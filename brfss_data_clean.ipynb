# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# Store filepath in a variable
file_one = Path("Resources/BRFSS__Table_of_Overweight_and_Obesity__BMI__20231102.csv")

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")

# %%
# Show just the header
file_one_df.head()
# Out:
#    Year Locationabbr Locationdesc                         Class  \
# 0  2020           AK       Alaska  Overweight and Obesity (BMI)
# 1  2019           AL      Alabama  Overweight and Obesity (BMI)
# 2  2019           AL      Alabama  Overweight and Obesity (BMI)
# 3  2019           AL      Alabama  Overweight and Obesity (BMI)
# 4  2019           AK       Alaska  Overweight and Obesity (BMI)
#
#             Topic                                           Question  \
# 0  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 1  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 2  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 3  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 4  BMI Categories  Weight classification by Body Mass Index (BMI)...
#
#                         Response                  Break_Out  \
# 0    Underweight (BMI 12.0-18.4)                      45-54
# 1    Underweight (BMI 12.0-18.4)                      35-44
# 2    Underweight (BMI 12.0-18.4)        Other, non-Hispanic
# 3    Underweight (BMI 12.0-18.4)  Multiracial, non-Hispanic
# 4  Normal Weight (BMI 18.5-24.9)        Asian, non-Hispanic
#
#   Break_Out_Category  Sample_Size  ...  \
# 0          Age Group            5  ...
# 1          Age Group            7  ...
# 2     Race/Ethnicity            1  ...
# 3     Race/Ethnicity            1  ...
# 4     Race/Ethnicity           16  ...
#
#                                  Data_Value_Footnote  DataSource  ClassId  \
# 0  Prevalence estimate not available if the unwei...       BRFSS  CLASS14
# 1  Prevalence estimate not available if the unwei...       BRFSS  CLASS14
# 2  Prevalence estimate not available if the unwei...       BRFSS  CLASS14
# 3  Prevalence estimate not available if the unwei...       BRFSS  CLASS14
# 4  Prevalence estimate not available if the unwei...       BRFSS  CLASS14
#
#    TopicId LocationID BreakoutID BreakOutCategoryID QuestionID ResponseID  \
# 0  TOPIC09          2      AGE04               CAT3   _BMI5CAT    RESP042
# 1  TOPIC09          1      AGE03               CAT3   _BMI5CAT    RESP042
# 2  TOPIC09          1     RACE06               CAT4   _BMI5CAT    RESP042
# 3  TOPIC09          1     RACE07               CAT4   _BMI5CAT    RESP042
# 4  TOPIC09          2     RACE04               CAT4   _BMI5CAT    RESP041
#
#                                 GeoLocation
# 0  (64.84507995700051, -147.72205903599973)
# 1   (32.84057112200048, -86.63186076199969)
# 2   (32.84057112200048, -86.63186076199969)
# 3   (32.84057112200048, -86.63186076199969)
# 4  (64.84507995700051, -147.72205903599973)
#
# [5 rows x 27 columns]

# %%
# Filter only the needed columns
cleaned_columns_df = file_one_df[["Year", "Locationabbr", "Locationdesc", "Response", "Break_Out", "Break_Out_Category", "Sample_Size", "Data_value", "GeoLocation"]];
print(cleaned_columns_df.count())
cleaned_columns_df.head()
unique_years = cleaned_columns_df['Year'].unique()
count = len(unique_years)
print(f"Number of unique_years: {count}")
# Out:
# Year                  64594
# Locationabbr          64594
# Locationdesc          64594
# Response              64594
# Break_Out             64594
# Break_Out_Category    64594
# Sample_Size           64594
# Data_value            51506
# GeoLocation           64498
# dtype: int64
# Number of unique_years: 12

# %%
# Filter need rows only starting from year 2014-2019
cleaned_columns_df = cleaned_columns_df.loc[(cleaned_columns_df["Year"]>=2014) & (cleaned_columns_df["Year"]<=2019), :]
print(cleaned_columns_df.count())
cleaned_columns_df.head()


# group_A_X = temp.get_group(('2015', '2016'))
# group_A_X.head()
unique_years = cleaned_columns_df['Year'].unique()
count = len(unique_years)
print(f"Number of unique_years: {count}")
# Out:
# Year                  32450
# Locationabbr          32450
# Locationdesc          32450
# Response              32450
# Break_Out             32450
# Break_Out_Category    32450
# Sample_Size           32450
# Data_value            25462
# GeoLocation           32402
# dtype: int64
# Number of unique_years: 6

# %%
# Filter Break_Out_Category	 to "Age Group" only to filter out the Data_value with entries
cleaned_columns_df['Break_Out_Category'] = cleaned_columns_df['Break_Out_Category'].astype(str)
print(cleaned_columns_df.dtypes)
cleaned_columns_df = cleaned_columns_df.loc[(cleaned_columns_df["Break_Out_Category"].str.contains("Age Group")), :]
print(cleaned_columns_df.count())

cleaned_columns_df.head()


unique_years = cleaned_columns_df['Year'].unique()
count = len(unique_years)
print(f"Number of unique_years: {count}")
# Out:
# Year                    int64
# Locationabbr           object
# Locationdesc           object
# Response               object
# Break_Out              object
# Break_Out_Category     object
# Sample_Size             int64
# Data_value            float64
# GeoLocation            object
# dtype: object
# Year                  7632
# Locationabbr          7632
# Locationdesc          7632
# Response              7632
# Break_Out             7632
# Break_Out_Category    7632
# Sample_Size           7632
# Data_value            6594
# GeoLocation           7632
# dtype: int64
# Number of unique_years: 6

# %%
# Filter Response to "Obese" only to filter out the Data_value with entries
cleaned_columns_df['Response'] = cleaned_columns_df['Response'].astype(str)
print(cleaned_columns_df.dtypes)
cleaned_columns_df = cleaned_columns_df.loc[(cleaned_columns_df["Response"].str.contains("Obese")) | (cleaned_columns_df["Response"].str.contains("Overweight")), :]
print(cleaned_columns_df.count())
cleaned_columns_df

unique_years = cleaned_columns_df['Year'].unique()
count = len(unique_years)
print(f"Number of unique_years: {count}")
# Out:
# Year                    int64
# Locationabbr           object
# Locationdesc           object
# Response               object
# Break_Out              object
# Break_Out_Category     object
# Sample_Size             int64
# Data_value            float64
# GeoLocation            object
# dtype: object
# Year                  3816
# Locationabbr          3816
# Locationdesc          3816
# Response              3816
# Break_Out             3816
# Break_Out_Category    3816
# Sample_Size           3816
# Data_value            3813
# GeoLocation           3816
# dtype: int64
# Number of unique_years: 6

# %%
# grouped_df = cleaned_columns_df.groupby(["Locationabbr"])
# cleaned_columns_df["Locationabbr"].value_counts()

unique_states = cleaned_columns_df['Locationabbr'].unique()
count = len(unique_states)
print(f"Number of unique states: {count}")

unique_years = cleaned_columns_df['Year'].unique()
count = len(unique_years)
print(f"Number of unique_years: {count}")
# Out:
# Number of unique states: 54
# Number of unique_years: 6

# %%
cleaned_columns_df['GeoLocation']=cleaned_columns_df['GeoLocation'].str.replace("(","")
cleaned_columns_df['GeoLocation']=cleaned_columns_df['GeoLocation'].str.replace(")","")
# Out:
# C:\Users\thinh\AppData\Local\Temp\ipykernel_26372\366922757.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   cleaned_columns_df['GeoLocation']=cleaned_columns_df['GeoLocation'].str.replace("(","")
# C:\Users\thinh\AppData\Local\Temp\ipykernel_26372\366922757.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   cleaned_columns_df['GeoLocation']=cleaned_columns_df['GeoLocation'].str.replace(")","")

# %%
cleaned_columns_df.head()
# Out:
#       Year Locationabbr Locationdesc                    Response Break_Out  \
# 885   2019           DE     Delaware     Obese (BMI 30.0 - 99.8)     55-64
# 1754  2019           KS       Kansas     Obese (BMI 30.0 - 99.8)     25-34
# 2056  2019           LA    Louisiana     Obese (BMI 30.0 - 99.8)     55-64
# 2058  2019           KY     Kentucky  Overweight (BMI 25.0-29.9)     35-44
# 2794  2019           NY     New York  Overweight (BMI 25.0-29.9)     45-54
#
#      Break_Out_Category  Sample_Size  Data_value  \
# 885           Age Group          299        40.1
# 1754          Age Group          386        34.3
# 2056          Age Group          395        41.9
# 2058          Age Group          294        35.6
# 2794          Age Group          713        37.2
#
#                                  GeoLocation
# 885   39.008830667000495, -75.57774116799965
# 1754   38.34774030000045, -98.20078122699965
# 2056   31.31266064400046, -92.44568007099969
# 2058  37.645970271000465, -84.77497104799966
# 2794   42.82700103200045, -75.54397042699964

# %%
cleaned_columns_df[['lat', 'long']] = cleaned_columns_df['GeoLocation'].str.split(', ', expand=True)

# %%
cleaned_columns_df = cleaned_columns_df.drop('GeoLocation', axis=1)

# %%
cleaned_columns_df.head()
# Out:
#       Year Locationabbr Locationdesc                    Response Break_Out  \
# 885   2019           DE     Delaware     Obese (BMI 30.0 - 99.8)     55-64
# 1754  2019           KS       Kansas     Obese (BMI 30.0 - 99.8)     25-34
# 2056  2019           LA    Louisiana     Obese (BMI 30.0 - 99.8)     55-64
# 2058  2019           KY     Kentucky  Overweight (BMI 25.0-29.9)     35-44
# 2794  2019           NY     New York  Overweight (BMI 25.0-29.9)     45-54
#
#      Break_Out_Category  Sample_Size  Data_value                 lat  \
# 885           Age Group          299        40.1  39.008830667000495
# 1754          Age Group          386        34.3   38.34774030000045
# 2056          Age Group          395        41.9   31.31266064400046
# 2058          Age Group          294        35.6  37.645970271000465
# 2794          Age Group          713        37.2   42.82700103200045
#
#                     long
# 885   -75.57774116799965
# 1754  -98.20078122699965
# 2056  -92.44568007099969
# 2058  -84.77497104799966
# 2794  -75.54397042699964

# %%
cleaned_columns_df = cleaned_columns_df.rename(columns={'Locationabbr': 'state_code'})
cleaned_columns_df = cleaned_columns_df.rename(columns={'lat': 'latitude'})
cleaned_columns_df = cleaned_columns_df.rename(columns={'long': 'longtitude'})
cleaned_columns_df
# Out:
#        Year state_code Locationdesc                    Response Break_Out  \
# 885    2019         DE     Delaware     Obese (BMI 30.0 - 99.8)     55-64
# 1754   2019         KS       Kansas     Obese (BMI 30.0 - 99.8)     25-34
# 2056   2019         LA    Louisiana     Obese (BMI 30.0 - 99.8)     55-64
# 2058   2019         KY     Kentucky  Overweight (BMI 25.0-29.9)     35-44
# 2794   2019         NY     New York  Overweight (BMI 25.0-29.9)     45-54
# ...     ...        ...          ...                         ...       ...
# 64512  2018         VA     Virginia  Overweight (BMI 25.0-29.9)     45-54
# 64514  2017         MS  Mississippi  Overweight (bmi 25.0-29.9)     55-64
# 64551  2016         NV       Nevada     Obese (bmi 30.0 - 99.8)     45-54
# 64577  2015         CT  Connecticut  Overweight (bmi 25.0-29.9)     35-44
# 64593  2017         MO     Missouri     Obese (bmi 30.0 - 99.8)     35-44
#
#       Break_Out_Category  Sample_Size  Data_value            latitude  \
# 885            Age Group          299        40.1  39.008830667000495
# 1754           Age Group          386        34.3   38.34774030000045
# 2056           Age Group          395        41.9   31.31266064400046
# 2058           Age Group          294        35.6  37.645970271000465
# 2794           Age Group          713        37.2   42.82700103200045
# ...                  ...          ...         ...                 ...
# 64512          Age Group          542        35.0   37.54268067400045
# 64514          Age Group          377        32.3  32.745510099000455
# 64551          Age Group          186        30.7  39.493240390000494
# 64577          Age Group          421        37.3         41.56266102
# 64593          Age Group          267        34.9  38.635790776000476
#
#                 longtitude
# 885     -75.57774116799965
# 1754    -98.20078122699965
# 2056    -92.44568007099969
# 2058    -84.77497104799966
# 2794    -75.54397042699964
# ...                    ...
# 64512   -78.45789046299967
# 64514   -89.53803082499968
# 64551  -117.07184056399967
# 64577        -72.649840952
# 64593   -92.56630005299968
#
# [3816 rows x 10 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
cleaned_columns_df.to_csv("clean_data/BRFSS__Table_of_Overweight_and_Obesity__BMI__20231102_cleaned.csv", index=False, header=True)
