# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
import sqlite3
import pandas as pd

# %%
# Create engine using the sqlite database file
engine = create_engine("sqlite:///./database/project3_group6.sqlite")

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(autoload_with=engine)
Base.classes.keys()
# Out:
# ['death_rates', 'fast_food', 'us_states', 'gdp_state', 'overweight_obesity']

# %%
# Map classes
death_rates = Base.classes.death_rates
fast_food =  Base.classes.fast_food
us_states =  Base.classes.fast_food
gdp_state =  Base.classes.gdp_state
overweight_obesity =  Base.classes.overweight_obesity

# %%
# create a session
session = Session(engine)

# %%
# Create the inspector and connect it to the engine
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['death_rates',
#  'fast_food',
#  'gdp_state',
#  'overweight_obesity',
#  'sqlite_sequence',
#  'us_states']

# %%
us_states_df = pd.read_sql_table('us_states', engine)
us_states_df
# Out:
#    state_code            state_name
# 0          DE              Delaware
# 1          KS                Kansas
# 2          LA             Louisiana
# 3          KY              Kentucky
# 4          NY              New York
# 5          PA          Pennsylvania
# 6          GU                  Guam
# 7          IN               Indiana
# 8          PR           Puerto Rico
# 9          ID                 Idaho
# 10         FL               Florida
# 11         UT                  Utah
# 12         AR              Arkansas
# 13         NE              Nebraska
# 14         TN             Tennessee
# 15         TX                 Texas
# 16         VA              Virginia
# 17         HI                Hawaii
# 18         WI             Wisconsin
# 19         MN             Minnesota
# 20         RI          Rhode Island
# 21         NJ            New Jersey
# 22         ND          North Dakota
# 23         MD              Maryland
# 24         NV                Nevada
# 25         AK                Alaska
# 26         SC        South Carolina
# 27         IL              Illinois
# 28         MI              Michigan
# 29         OH                  Ohio
# 30         CT           Connecticut
# 31         OR                Oregon
# 32         AL               Alabama
# 33         WA            Washington
# 34         GA               Georgia
# 35         AZ               Arizona
# 36         MO              Missouri
# 37         DC  District of Columbia
# 38         NM            New Mexico
# 39         OK              Oklahoma
# 40         NC        North Carolina
# 41         WY               Wyoming
# 42         VT               Vermont
# 43         WV         West Virginia
# 44         CA            California
# 45         MA         Massachusetts
# 46         SD          South Dakota
# 47         CO              Colorado
# 48         MS           Mississippi
# 49         ME                 Maine
# 50         MT               Montana
# 51         IA                  Iowa
# 52         NH         New Hampshire
# 53         VI        Virgin Islands

# %%
overweight_obesity_df = pd.read_sql_table('overweight_obesity', engine)
overweight_obesity_df.head(10)
# Out:
#    ID  date_year state_code                    response break_out  \
# 0   1       2019         DE     Obese (BMI 30.0 - 99.8)     55-64
# 1   2       2019         KS     Obese (BMI 30.0 - 99.8)     25-34
# 2   3       2019         LA     Obese (BMI 30.0 - 99.8)     55-64
# 3   4       2019         KY  Overweight (BMI 25.0-29.9)     35-44
# 4   5       2019         NY  Overweight (BMI 25.0-29.9)     45-54
# 5   6       2019         PA     Obese (BMI 30.0 - 99.8)     18-24
# 6   7       2019         GU     Obese (BMI 30.0 - 99.8)     18-24
# 7   8       2014         GU     Obese (BMI 30.0 - 99.8)     25-34
# 8   9       2014         IN  Overweight (BMI 25.0-29.9)     25-34
# 9  10       2014         PR  Overweight (BMI 25.0-29.9)     45-54
#
#   break_out_category  sample_size  data_value   latitude   longitude
# 0          Age Group          299        40.1  39.008831  -75.577741
# 1          Age Group          386        34.3  38.347740  -98.200781
# 2          Age Group          395        41.9  31.312661  -92.445680
# 3          Age Group          294        35.6  37.645970  -84.774971
# 4          Age Group          713        37.2  42.827001  -75.543970
# 5          Age Group           94        23.3  40.793730  -77.860700
# 6          Age Group           39        22.2  13.444304  144.793731
# 7          Age Group          148        34.6  13.444304  144.793731
# 8          Age Group          249        32.8  39.766910  -86.149960
# 9          Age Group          401        42.7  18.220833  -66.590149

# %%
# Extract unique state codes with latitude and longitude
state_lat_long_df = overweight_obesity_df[['state_code', 'latitude', 'longitude']].drop_duplicates()
state_lat_long_df.head()
# Out:
#   state_code   latitude  longitude
# 0         DE  39.008831 -75.577741
# 1         KS  38.347740 -98.200781
# 2         LA  31.312661 -92.445680
# 3         KY  37.645970 -84.774971
# 4         NY  42.827001 -75.543970

# %%
merged_df = pd.merge(state_lat_long_df, us_states_df, on='state_code', how='left')
merged_df.drop_duplicates(subset=['state_name']).reset_index(drop=True)
merged_df.head(20)
# Out:
#    state_code   latitude   longitude    state_name
# 0          DE  39.008831  -75.577741      Delaware
# 1          KS  38.347740  -98.200781        Kansas
# 2          LA  31.312661  -92.445680     Louisiana
# 3          KY  37.645970  -84.774971      Kentucky
# 4          NY  42.827001  -75.543970      New York
# 5          PA  40.793730  -77.860700  Pennsylvania
# 6          GU  13.444304  144.793731          Guam
# 7          IN  39.766910  -86.149960       Indiana
# 8          PR  18.220833  -66.590149   Puerto Rico
# 9          ID  43.682630 -114.363730         Idaho
# 10         FL  28.932040  -81.928961       Florida
# 11         UT  39.360700 -111.587131          Utah
# 12         AR  34.748650  -92.274491      Arkansas
# 13         NE  41.641041  -99.365721      Nebraska
# 14         TN  35.680941  -85.774491     Tennessee
# 15         TX  31.827240  -99.426770         Texas
# 16         VA  37.542681  -78.457890      Virginia
# 17         HI  21.304850 -157.857749        Hawaii
# 18         WI  44.393191  -89.816371     Wisconsin
# 19         MN  46.355649  -94.794201     Minnesota

# %%
gdp_state_df = pd.read_sql_table('gdp_state', engine)
gdp_state_df.head(10)
# Out:
#    ID            state_name                description  amount_2014  \
# 0   1         United States  GDP (Billions of Dollars)   16932.0510
# 1   2               Alabama  GDP (Billions of Dollars)     189.8863
# 2   3                Alaska  GDP (Billions of Dollars)      54.1882
# 3   4               Arizona  GDP (Billions of Dollars)     276.9489
# 4   5              Arkansas  GDP (Billions of Dollars)     111.7345
# 5   6            California  GDP (Billions of Dollars)    2256.0547
# 6   7              Colorado  GDP (Billions of Dollars)     298.6553
# 7   8           Connecticut  GDP (Billions of Dollars)     235.7809
# 8   9              Delaware  GDP (Billions of Dollars)      64.9401
# 9  10  District of Columbia  GDP (Billions of Dollars)     114.5536
#
#    amount_2015  amount_2016  amount_2017  amount_2018  amount_2019
# 0   17390.2950   17680.2740   18076.6510   18609.0780   19036.0520
# 1     191.3352     194.2838     196.9749     200.3726     203.4327
# 2      54.7408      54.2466      54.2787      53.3270      53.4338
# 3     282.5770     291.2752     303.6061     314.8275     325.3953
# 4     112.3510     112.7981     113.8502     115.8852     117.1262
# 5    2357.4529    2427.8946    2538.2040    2644.0612    2729.2258
# 6     312.4097     318.9534     329.9133     342.7332     358.4385
# 7     242.7065     243.2867     247.0359     249.0748     251.5682
# 8      66.7935      63.0013      60.3575      61.4251      64.1435
# 9     116.8084     119.6443     120.7594     123.6805     124.5972

# %%
location_gdp_df = pd.merge(gdp_state_df, merged_df, on='state_name', how='left')

# %%
location_gdp_df = location_gdp_df.drop_duplicates(subset=['state_name']).reset_index(drop=True)

# %%
decimals = 2  # Set the desired number of decimals

# Round columns to the specified number of decimals
location_gdp_df['amount_2014'] = location_gdp_df['amount_2014'].round(decimals)
location_gdp_df['amount_2015'] = location_gdp_df['amount_2015'].round(decimals)
location_gdp_df['amount_2016'] = location_gdp_df['amount_2016'].round(decimals)
location_gdp_df['amount_2017'] = location_gdp_df['amount_2017'].round(decimals)
location_gdp_df['amount_2018'] = location_gdp_df['amount_2018'].round(decimals)
location_gdp_df['amount_2019'] = location_gdp_df['amount_2019'].round(decimals)
location_gdp_df
# Out:
#     ID            state_name                description  amount_2014  \
# 0    2               Alabama  GDP (Billions of Dollars)       189.89
# 1    3                Alaska  GDP (Billions of Dollars)        54.19
# 2    4               Arizona  GDP (Billions of Dollars)       276.95
# 3    5              Arkansas  GDP (Billions of Dollars)       111.73
# 4    6            California  GDP (Billions of Dollars)      2256.05
# 5    7              Colorado  GDP (Billions of Dollars)       298.66
# 6    8           Connecticut  GDP (Billions of Dollars)       235.78
# 7    9              Delaware  GDP (Billions of Dollars)        64.94
# 8   10  District of Columbia  GDP (Billions of Dollars)       114.55
# 9   11               Florida  GDP (Billions of Dollars)       817.23
# 10  12               Georgia  GDP (Billions of Dollars)       470.01
# 11  13                Hawaii  GDP (Billions of Dollars)        73.51
# 12  14                 Idaho  GDP (Billions of Dollars)        62.45
# 13  15              Illinois  GDP (Billions of Dollars)       741.19
# 14  16               Indiana  GDP (Billions of Dollars)       316.78
# 15  17                  Iowa  GDP (Billions of Dollars)       166.62
# 16  18                Kansas  GDP (Billions of Dollars)       145.34
# 17  19              Kentucky  GDP (Billions of Dollars)       181.47
# 18  20             Louisiana  GDP (Billions of Dollars)       235.36
# 19  21                 Maine  GDP (Billions of Dollars)        54.04
# 20  22              Maryland  GDP (Billions of Dollars)       339.60
# 21  23         Massachusetts  GDP (Billions of Dollars)       451.57
# 22  24              Michigan  GDP (Billions of Dollars)       434.31
# 23  25             Minnesota  GDP (Billions of Dollars)       314.09
# 24  26           Mississippi  GDP (Billions of Dollars)       100.28
# 25  27              Missouri  GDP (Billions of Dollars)       276.08
# 26  28               Montana  GDP (Billions of Dollars)        43.83
# 27  29              Nebraska  GDP (Billions of Dollars)       107.94
# 28  30                Nevada  GDP (Billions of Dollars)       130.90
# 29  31         New Hampshire  GDP (Billions of Dollars)        70.21
# 30  32            New Jersey  GDP (Billions of Dollars)       522.17
# 31  33            New Mexico  GDP (Billions of Dollars)        88.99
# 32  34              New York  GDP (Billions of Dollars)      1353.41
# 33  35        North Carolina  GDP (Billions of Dollars)       462.25
# 34  36          North Dakota  GDP (Billions of Dollars)        57.79
# 35  37                  Ohio  GDP (Billions of Dollars)       574.18
# 36  38              Oklahoma  GDP (Billions of Dollars)       189.36
# 37  39                Oregon  GDP (Billions of Dollars)       181.22
# 38  40          Pennsylvania  GDP (Billions of Dollars)       669.64
# 39  41          Rhode Island  GDP (Billions of Dollars)        52.29
# 40  42        South Carolina  GDP (Billions of Dollars)       185.99
# 41  43          South Dakota  GDP (Billions of Dollars)        44.85
# 42  44             Tennessee  GDP (Billions of Dollars)       294.13
# 43  45                 Texas  GDP (Billions of Dollars)      1529.62
# 44  46                  Utah  GDP (Billions of Dollars)       136.99
# 45  47               Vermont  GDP (Billions of Dollars)        28.91
# 46  48              Virginia  GDP (Billions of Dollars)       447.68
# 47  49            Washington  GDP (Billions of Dollars)       424.47
# 48  50         West Virginia  GDP (Billions of Dollars)        70.53
# 49  51             Wisconsin  GDP (Billions of Dollars)       283.98
# 50  52               Wyoming  GDP (Billions of Dollars)        39.56
#
#     amount_2015  amount_2016  amount_2017  amount_2018  amount_2019  \
# 0        191.34       194.28       196.97       200.37       203.43
# 1         54.74        54.25        54.28        53.33        53.43
# 2        282.58       291.28       303.61       314.83       325.40
# 3        112.35       112.80       113.85       115.89       117.13
# 4       2357.45      2427.89      2538.20      2644.06      2729.23
# 5        312.41       318.95       329.91       342.73       358.44
# 6        242.71       243.29       247.04       249.07       251.57
# 7         66.79        63.00        60.36        61.43        64.14
# 8        116.81       119.64       120.76       123.68       124.60
# 9        852.24       881.54       912.69       941.63       965.67
# 10       489.18       506.82       523.81       538.60       557.36
# 11        75.87        77.30        78.95        79.85        79.21
# 12        63.08        65.48        66.94        70.86        74.16
# 13       751.75       749.33       753.03       771.70       776.00
# 14       313.75       319.60       325.00       336.33       337.90
# 15       171.13       170.39       170.89       173.55       173.72
# 16       148.81       153.70       155.51       158.73       159.83
# 17       182.92       184.12       185.92       187.93       192.97
# 18       233.02       228.43       233.35       237.30       237.04
# 19        54.43        55.57        56.47        58.10        59.55
# 20       348.15       360.08       366.20       367.98       368.06
# 21       468.06       475.35       482.81       501.54       514.17
# 22       443.83       452.33       457.61       466.56       467.11
# 23       318.91       324.03       327.48       336.89       340.56
# 24       100.48       101.26       101.25       100.87       100.98
# 25       279.02       279.11       281.25       284.54       290.62
# 26        45.40        44.44        45.97        46.58        46.89
# 27       111.40       112.61       114.14       116.79       118.60
# 28       136.35       140.08       145.49       150.45       156.96
# 29        72.04        73.57        73.97        75.43        76.82
# 30       529.95       535.06       537.58       550.06       559.65
# 31        89.70        89.15        88.96        90.93        94.90
# 32      1373.64      1403.23      1419.11      1458.38      1500.83
# 33       475.10       482.97       495.22       501.56       512.83
# 34        56.54        52.97        54.19        55.91        56.39
# 35       578.85       583.95       593.64       597.93       613.25
# 36       197.07       193.03       194.02       197.45       201.16
# 37       189.95       198.08       205.52       214.90       219.59
# 38       682.47       688.36       694.87       704.03       715.06
# 39        52.82        52.90        52.69        52.55        53.41
# 40       192.02       198.01       202.51       207.10       213.24
# 41        45.66        46.08        45.78        46.30        46.65
# 42       304.48       310.14       318.96       323.54       331.18
# 43      1605.90      1619.95      1659.45      1728.30      1779.78
# 44       141.72       147.96       154.76       164.62       172.04
# 45        29.12        29.41        29.49        29.60        29.94
# 46       455.16       459.97       467.36       477.92       489.20
# 47       441.95       458.26       482.01       515.03       533.15
# 48        70.66        70.01        71.43        73.17        72.63
# 49       289.08       291.92       291.92       299.06       303.67
# 50        40.42        38.19        37.52        38.08        38.45
#
#    state_code   latitude   longitude
# 0          AL  32.840571  -86.631861
# 1          AK  64.845080 -147.722059
# 2          AZ  34.865970 -111.763811
# 3          AR  34.748650  -92.274491
# 4          CA  37.638640 -121.000000
# 5          CO  38.843841 -106.133611
# 6          CT  41.562661  -72.649841
# 7          DE  39.008831  -75.577741
# 8          DC  38.890371  -77.031961
# 9          FL  28.932040  -81.928961
# 10         GA  32.839681  -83.627580
# 11         HI  21.304850 -157.857749
# 12         ID  43.682630 -114.363730
# 13         IL  40.485010  -88.997710
# 14         IN  39.766910  -86.149960
# 15         IA  42.469401  -93.816491
# 16         KS  38.347740  -98.200781
# 17         KY  37.645970  -84.774971
# 18         LA  31.312661  -92.445680
# 19         ME  45.254229  -68.985031
# 20         MD  39.290581  -76.609260
# 21         MA  42.276870  -72.082691
# 22         MI  44.661320  -84.714390
# 23         MN  46.355649  -94.794201
# 24         MS  32.745510  -89.538031
# 25         MO  38.635791  -92.566300
# 26         MT  47.066529 -109.424421
# 27         NE  41.641041  -99.365721
# 28         NV  39.493240 -117.071841
# 29         NH  43.655950  -71.500361
# 30         NJ  40.130570  -74.273691
# 31         NM  34.520881 -106.240581
# 32         NY  42.827001  -75.543970
# 33         NC  35.466221  -79.159250
# 34         ND  47.475320 -100.118421
# 35         OH  40.060210  -82.404260
# 36         OK  35.472031  -97.521070
# 37         OR  44.567449 -120.155031
# 38         PA  40.793730  -77.860700
# 39         RI  41.708280  -71.522470
# 40         SC  33.998821  -81.045371
# 41         SD  44.353130 -100.373531
# 42         TN  35.680941  -85.774491
# 43         TX  31.827240  -99.426770
# 44         UT  39.360700 -111.587131
# 45         VT  43.625381  -72.517641
# 46         VA  37.542681  -78.457890
# 47         WA  47.522279 -120.470011
# 48         WV  38.665510  -80.712640
# 49         WI  44.393191  -89.816371
# 50         WY  43.235541 -108.109830

# %%
location_gdp_df.to_csv("clean_data/location_gdp.csv", index=False, header=True)

# %%
overweight_obesity_df.head(10)
# Out:
#    ID  date_year state_code                    response break_out  \
# 0   1       2019         DE     Obese (BMI 30.0 - 99.8)     55-64
# 1   2       2019         KS     Obese (BMI 30.0 - 99.8)     25-34
# 2   3       2019         LA     Obese (BMI 30.0 - 99.8)     55-64
# 3   4       2019         KY  Overweight (BMI 25.0-29.9)     35-44
# 4   5       2019         NY  Overweight (BMI 25.0-29.9)     45-54
# 5   6       2019         PA     Obese (BMI 30.0 - 99.8)     18-24
# 6   7       2019         GU     Obese (BMI 30.0 - 99.8)     18-24
# 7   8       2014         GU     Obese (BMI 30.0 - 99.8)     25-34
# 8   9       2014         IN  Overweight (BMI 25.0-29.9)     25-34
# 9  10       2014         PR  Overweight (BMI 25.0-29.9)     45-54
#
#   break_out_category  sample_size  data_value   latitude   longitude
# 0          Age Group          299        40.1  39.008831  -75.577741
# 1          Age Group          386        34.3  38.347740  -98.200781
# 2          Age Group          395        41.9  31.312661  -92.445680
# 3          Age Group          294        35.6  37.645970  -84.774971
# 4          Age Group          713        37.2  42.827001  -75.543970
# 5          Age Group           94        23.3  40.793730  -77.860700
# 6          Age Group           39        22.2  13.444304  144.793731
# 7          Age Group          148        34.6  13.444304  144.793731
# 8          Age Group          249        32.8  39.766910  -86.149960
# 9          Age Group          401        42.7  18.220833  -66.590149

# %%
# Convert 'date_year' to string to ensure it's treated as a categorical variable
overweight_obesity_df['date_year'] = overweight_obesity_df['date_year'].astype(str)

# Filter data for the year 2019
df_2014 = overweight_obesity_df[overweight_obesity_df['date_year'] == '2014']
df_2015 = overweight_obesity_df[overweight_obesity_df['date_year'] == '2015']
df_2016 = overweight_obesity_df[overweight_obesity_df['date_year'] == '2016']
df_2017 = overweight_obesity_df[overweight_obesity_df['date_year'] == '2017']
df_2018 = overweight_obesity_df[overweight_obesity_df['date_year'] == '2018']
df_2019 = overweight_obesity_df[overweight_obesity_df['date_year'] == '2019']

# %%
# Group by 'state_code' and 'break_out', then calculate the average 'data_value'
average_data_value_2014 = df_2014.groupby(['state_code', 'break_out', 'latitude', 'longitude'])['data_value'].mean().reset_index()
average_data_value_2015 = df_2015.groupby(['state_code', 'break_out', 'latitude', 'longitude'])['data_value'].mean().reset_index()
average_data_value_2016 = df_2016.groupby(['state_code', 'break_out', 'latitude', 'longitude'])['data_value'].mean().reset_index()
average_data_value_2017 = df_2017.groupby(['state_code', 'break_out', 'latitude', 'longitude'])['data_value'].mean().reset_index()
average_data_value_2018 = df_2018.groupby(['state_code', 'break_out', 'latitude', 'longitude'])['data_value'].mean().reset_index()
average_data_value_2019 = df_2019.groupby(['state_code', 'break_out', 'latitude', 'longitude'])['data_value'].mean().reset_index()
# Out:
#     state_code break_out   latitude   longitude  data_value
# 0           AK     18-24  64.845080 -147.722059       21.90
# 1           AK     25-34  64.845080 -147.722059       29.10
# 2           AK     35-44  64.845080 -147.722059       34.75
# 3           AK     45-54  64.845080 -147.722059       35.50
# 4           AK     55-64  64.845080 -147.722059       36.60
# ..         ...       ...        ...         ...         ...
# 313         WY     25-34  43.235541 -108.109830       29.65
# 314         WY     35-44  43.235541 -108.109830       37.90
# 315         WY     45-54  43.235541 -108.109830       34.50
# 316         WY     55-64  43.235541 -108.109830       35.50
# 317         WY       65+  43.235541 -108.109830       32.30
#
# [318 rows x 5 columns]

# %%
# Group by 'state_code' and calculate the overall average 'data_value'
overall_average_data_value_2014 = average_data_value_2014.groupby(['state_code','latitude', 'longitude'])['data_value'].mean().reset_index()
overall_average_data_value_2015 = average_data_value_2015.groupby(['state_code','latitude', 'longitude'])['data_value'].mean().reset_index()
overall_average_data_value_2016 = average_data_value_2016.groupby(['state_code','latitude', 'longitude'])['data_value'].mean().reset_index()
overall_average_data_value_2017 = average_data_value_2017.groupby(['state_code','latitude', 'longitude'])['data_value'].mean().reset_index()
overall_average_data_value_2018 = average_data_value_2018.groupby(['state_code','latitude', 'longitude'])['data_value'].mean().reset_index()
overall_average_data_value_2019 = average_data_value_2019.groupby(['state_code','latitude', 'longitude'])['data_value'].mean().reset_index()

# %%
import folium
import fiona
import geopandas as gpd
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster
import math

# %% [markdown]
# 2014 MAP

# %%
#creating the base map
m= folium.Map(location = [38.27312, -98.5821872], zoom_start = 4)

#creating bubble map with restaurant counts per state.
#Loop through each row in the dataframe
for i in range(0,len(location_gdp_df)):
   folium.Circle(
      location=[overall_average_data_value_2014.iloc[i]['latitude'], overall_average_data_value_2014.iloc[i]['longitude']],
      popup=f"GDP 2014: {location_gdp_df.iloc[i]['amount_2014']} (Billions of Dollars)",
      radius=float(location_gdp_df.iloc[i]['amount_2014'])*200,
      color='crimson',
      fill=True,
      fill_color='crimson'
      ).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee6efe2c853e2b827e9273da54f3fc3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee6efe2c853e2b827e9273da54f3fc3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee6efe2c853e2b827e9273da54f3fc3f = L.map(
#                 &quot;map_ee6efe2c853e2b827e9273da54f3fc3f&quot;,
#                 {
#                     center: [38.27312, -98.5821872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c98dfa1464f007080f3ed282e10ee0b8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_c98dfa1464f007080f3ed282e10ee0b8.addTo(map_ee6efe2c853e2b827e9273da54f3fc3f);
#
#             var circle_55e3fa952a28f292f33f969d9cdd4031 = L.circle(
#                 [64.845079957001, -147.722059036],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 37978.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ee6efe2c853e2b827e9273da54f3fc3f);
#
#
#         var popup_c836557ef8a64926c6f3f72787993dcc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b4e34c7b1fea03cb31077b6d3c58c2a = $(`&lt;div id=&quot;html_7b4e34c7b1fea03cb31077b6d3c58c2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2014: 189.89 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_c836557ef8a64926c6f3f72787993dcc.setContent(html_7b4e34c7b1fea03cb31077b6d3c58c2a);
#
#
#
#         circle_55e3fa952a28f292f33f969d9cdd4031.bindPopup(popup_c836557ef8a64926c6f3f72787993dcc)
#         ;
#
#
#
#
#             var circle_8363a3c8121917eaaaad72f815dc3d3e = L.circle(
#                 [32.840571122, -86.631860762],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10838.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ee6efe2c853e2b827e9273da54f3fc3f);
#
#
#         var popup_b2afbde7715e34ac7d52e700a52b2ada = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68f37554c34fa0cf51707ccab30f15b0 = $(`&lt;div id=&quot;html_68f37554c34fa0cf51707ccab30f15b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2014: 54.19 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_b2afbde7715e34ac7d52e700a52b2ada.setContent(html_68f37554c34fa0cf51707ccab30f15b0);
#
#
#
#         circle_8363a3c8121917eaaaad72f815dc3d3e.bindPopup(popup_b2afbde7715e34ac7d52e700a52b2ada)
#         ;
#
#
#
#
#             var circle_d236cad805533ca9fd7b7d82c326bf6e = L.circle(
#                 [34.748650124, -92.274490743],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 55390.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ee6efe2c853e2b827e9273da54f3fc3f);
#
#
#         var popup_8cea533161f0d3eccaddce17f2c3e83f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53e3c7df31c63113411cbb8d3524a7f2 = $(`&lt;div id=&quot;html_53e3c7df31c63113411cbb8d3524a7f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2014: 276.95 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_8cea533161f0d3eccaddce17f2c3e83f.setContent(html_53e3c7df31c63113411cbb8d3524a7f2);
#
#
#
#         circle_d236cad805533ca9fd7b7d82c326bf6e.bindPopup(popup_8cea533161f0d3eccaddce17f2c3e83f)
#         ;
#
#
#
#
#             var circle_1525205351b0f5b838f68b31716da691 = L.circle(
#                 [34.86597028, -111.763811277],
#                 {&quot;bubblingMouseEvents&

# %%
# Add a HeatMap map to the base map for Diabeties data
lats_longs_weight = list(map(list, zip(overall_average_data_value_2014["latitude"],
                          overall_average_data_value_2014["longitude"],
                          overall_average_data_value_2014["data_value"]
                         )
               )
           )

#Creating a title for the layers in map#creating the base map
m= folium.Map(location = [38.27312, -98.5821872], zoom_start = 4)

#creating bubble map with restaurant counts per state.
#Loop through each row in the dataframe
for i in range(0,len(location_gdp_df)):
   folium.Circle(
      location=[overall_average_data_value_2015.iloc[i]['latitude'], overall_average_data_value_2015.iloc[i]['longitude']],
      popup=f"GDP 2015: {location_gdp_df.iloc[i]['amount_2015']} (Billions of Dollars)",
      radius=float(location_gdp_df.iloc[i]['amount_2015'])*200,
      color='crimson',
      fill=True,
      fill_color='crimson'
      ).add_to(m)
    
m
fg = folium.FeatureGroup(name="Obesity HeatMap")
fg.add_child(HeatMap(lats_longs_weight))
m.add_child(fg)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9529215ad997c71d7d909e7df50746d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9529215ad997c71d7d909e7df50746d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9529215ad997c71d7d909e7df50746d8 = L.map(
#                 &quot;map_9529215ad997c71d7d909e7df50746d8&quot;,
#                 {
#                     center: [38.27312, -98.5821872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_411bd24ad91debf8f6434b2e06587dba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_411bd24ad91debf8f6434b2e06587dba.addTo(map_9529215ad997c71d7d909e7df50746d8);
#
#             var circle_c0dd1d5e3f34a753428d525f146b33d8 = L.circle(
#                 [64.845079957001, -147.722059036],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 37978.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9529215ad997c71d7d909e7df50746d8);
#
#
#         var popup_e13f457fa7722c346bf588d0b55d6695 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a69184452c9c1bfcc02c23418600af37 = $(`&lt;div id=&quot;html_a69184452c9c1bfcc02c23418600af37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2014: 189.89 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_e13f457fa7722c346bf588d0b55d6695.setContent(html_a69184452c9c1bfcc02c23418600af37);
#
#
#
#         circle_c0dd1d5e3f34a753428d525f146b33d8.bindPopup(popup_e13f457fa7722c346bf588d0b55d6695)
#         ;
#
#
#
#
#             var circle_de10b9205ea19b53bf250721cee650ec = L.circle(
#                 [32.840571122, -86.631860762],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10838.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9529215ad997c71d7d909e7df50746d8);
#
#
#         var popup_10182c036cc5f6e7634f92115086046c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6041ce5c899c4650523155968129f794 = $(`&lt;div id=&quot;html_6041ce5c899c4650523155968129f794&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2014: 54.19 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_10182c036cc5f6e7634f92115086046c.setContent(html_6041ce5c899c4650523155968129f794);
#
#
#
#         circle_de10b9205ea19b53bf250721cee650ec.bindPopup(popup_10182c036cc5f6e7634f92115086046c)
#         ;
#
#
#
#
#             var circle_cb2765e920b57d4cfdb20558b8b119f3 = L.circle(
#                 [34.748650124, -92.274490743],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 55390.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9529215ad997c71d7d909e7df50746d8);
#
#
#         var popup_88643edf3bd1ea927155885619f2573c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_647c253920b378203bd7ec83a0f404a4 = $(`&lt;div id=&quot;html_647c253920b378203bd7ec83a0f404a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2014: 276.95 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_88643edf3bd1ea927155885619f2573c.setContent(html_647c253920b378203bd7ec83a0f404a4);
#
#
#
#         circle_cb2765e920b57d4cfdb20558b8b119f3.bindPopup(popup_88643edf3bd1ea927155885619f2573c)
#         ;

# %% [markdown]
# 2015 MAP

# %%
#creating the base map
m= folium.Map(location = [38.27312, -98.5821872], zoom_start = 4)

#creating bubble map with restaurant counts per state.
#Loop through each row in the dataframe
for i in range(0,len(location_gdp_df)):
   folium.Circle(
      location=[overall_average_data_value_2015.iloc[i]['latitude'], overall_average_data_value_2015.iloc[i]['longitude']],
      popup=f"GDP 2015: {location_gdp_df.iloc[i]['amount_2015']} (Billions of Dollars)",
      radius=float(location_gdp_df.iloc[i]['amount_2015'])*200,
      color='crimson',
      fill=True,
      fill_color='crimson'
      ).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36b3fb1e2249065ddde99d7839c41e61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36b3fb1e2249065ddde99d7839c41e61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36b3fb1e2249065ddde99d7839c41e61 = L.map(
#                 &quot;map_36b3fb1e2249065ddde99d7839c41e61&quot;,
#                 {
#                     center: [38.27312, -98.5821872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0c13464287ddfded986e0fdb5ae25a5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_f0c13464287ddfded986e0fdb5ae25a5.addTo(map_36b3fb1e2249065ddde99d7839c41e61);
#
#             var circle_4a07b8d89fc3f4f74eb03f3030685cc6 = L.circle(
#                 [64.845079957001, -147.722059036],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 38268.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_36b3fb1e2249065ddde99d7839c41e61);
#
#
#         var popup_02425f1354b93ec1fb182617803ab367 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_364872e1dd8438b9bbb55a9ef4e258b5 = $(`&lt;div id=&quot;html_364872e1dd8438b9bbb55a9ef4e258b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2015: 191.34 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_02425f1354b93ec1fb182617803ab367.setContent(html_364872e1dd8438b9bbb55a9ef4e258b5);
#
#
#
#         circle_4a07b8d89fc3f4f74eb03f3030685cc6.bindPopup(popup_02425f1354b93ec1fb182617803ab367)
#         ;
#
#
#
#
#             var circle_8707030d21fbef5812c5350550d3879b = L.circle(
#                 [32.840571122, -86.631860762],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10948.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_36b3fb1e2249065ddde99d7839c41e61);
#
#
#         var popup_e9c75ff96eb9ec8989ecc20762949ff4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b1576bf2147b395335a8dac49e5f9f4 = $(`&lt;div id=&quot;html_2b1576bf2147b395335a8dac49e5f9f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2015: 54.74 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_e9c75ff96eb9ec8989ecc20762949ff4.setContent(html_2b1576bf2147b395335a8dac49e5f9f4);
#
#
#
#         circle_8707030d21fbef5812c5350550d3879b.bindPopup(popup_e9c75ff96eb9ec8989ecc20762949ff4)
#         ;
#
#
#
#
#             var circle_9ea2bc8fc933e1fcb6b365a5e3169a21 = L.circle(
#                 [34.748650124, -92.274490743],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 56516.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_36b3fb1e2249065ddde99d7839c41e61);
#
#
#         var popup_48e3a00f0a81c0c31803648f2292f381 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d221f18dfce48289a7813ac465bdb86e = $(`&lt;div id=&quot;html_d221f18dfce48289a7813ac465bdb86e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2015: 282.58 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_48e3a00f0a81c0c31803648f2292f381.setContent(html_d221f18dfce48289a7813ac465bdb86e);
#
#
#
#         circle_9ea2bc8fc933e1fcb6b365a5e3169a21.bindPopup(popup_48e3a00f0a81c0c31803648f2292f381)
#         ;
#
#
#
#
#             var circle_3d142fddd8297d9af239b541d16cbdcc = L.circle(
#                 [34.86597028, -111.763811277],
#                 {&quot;bubblingMouseEvents&

# %%
# Add a HeatMap map to the base map for Diabeties data
lats_longs_weight = list(map(list, zip(overall_average_data_value_2015["latitude"],
                          overall_average_data_value_2015["longitude"],
                          overall_average_data_value_2015["data_value"]
                         )
               )
           )

#Creating a title for the layers in map
fg = folium.FeatureGroup(name="Obesity HeatMap")
fg.add_child(HeatMap(lats_longs_weight))
m.add_child(fg)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36b3fb1e2249065ddde99d7839c41e61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36b3fb1e2249065ddde99d7839c41e61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36b3fb1e2249065ddde99d7839c41e61 = L.map(
#                 &quot;map_36b3fb1e2249065ddde99d7839c41e61&quot;,
#                 {
#                     center: [38.27312, -98.5821872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0c13464287ddfded986e0fdb5ae25a5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_f0c13464287ddfded986e0fdb5ae25a5.addTo(map_36b3fb1e2249065ddde99d7839c41e61);
#
#             var circle_4a07b8d89fc3f4f74eb03f3030685cc6 = L.circle(
#                 [64.845079957001, -147.722059036],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 38268.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_36b3fb1e2249065ddde99d7839c41e61);
#
#
#         var popup_02425f1354b93ec1fb182617803ab367 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_364872e1dd8438b9bbb55a9ef4e258b5 = $(`&lt;div id=&quot;html_364872e1dd8438b9bbb55a9ef4e258b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2015: 191.34 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_02425f1354b93ec1fb182617803ab367.setContent(html_364872e1dd8438b9bbb55a9ef4e258b5);
#
#
#
#         circle_4a07b8d89fc3f4f74eb03f3030685cc6.bindPopup(popup_02425f1354b93ec1fb182617803ab367)
#         ;
#
#
#
#
#             var circle_8707030d21fbef5812c5350550d3879b = L.circle(
#                 [32.840571122, -86.631860762],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10948.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_36b3fb1e2249065ddde99d7839c41e61);
#
#
#         var popup_e9c75ff96eb9ec8989ecc20762949ff4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b1576bf2147b395335a8dac49e5f9f4 = $(`&lt;div id=&quot;html_2b1576bf2147b395335a8dac49e5f9f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2015: 54.74 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_e9c75ff96eb9ec8989ecc20762949ff4.setContent(html_2b1576bf2147b395335a8dac49e5f9f4);
#
#
#
#         circle_8707030d21fbef5812c5350550d3879b.bindPopup(popup_e9c75ff96eb9ec8989ecc20762949ff4)
#         ;
#
#
#
#
#             var circle_9ea2bc8fc933e1fcb6b365a5e3169a21 = L.circle(
#                 [34.748650124, -92.274490743],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 56516.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_36b3fb1e2249065ddde99d7839c41e61);
#
#
#         var popup_48e3a00f0a81c0c31803648f2292f381 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d221f18dfce48289a7813ac465bdb86e = $(`&lt;div id=&quot;html_d221f18dfce48289a7813ac465bdb86e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2015: 282.58 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_48e3a00f0a81c0c31803648f2292f381.setContent(html_d221f18dfce48289a7813ac465bdb86e);
#
#
#
#         circle_9ea2bc8fc933e1fcb6b365a5e3169a21.bindPopup(popup_48e3a00f0a81c0c31803648f2292f381)
#         ;

# %% [markdown]
# 2016 MAP

# %%
#creating the base map
m= folium.Map(location = [38.27312, -98.5821872], zoom_start = 4)

#creating bubble map with restaurant counts per state.
#Loop through each row in the dataframe
for i in range(0,len(location_gdp_df)):
   folium.Circle(
      location=[overall_average_data_value_2016.iloc[i]['latitude'], overall_average_data_value_2016.iloc[i]['longitude']],
      popup=f"GDP 2016: {location_gdp_df.iloc[i]['amount_2016']} (Billions of Dollars)",
      radius=float(location_gdp_df.iloc[i]['amount_2016'])*200,
      color='crimson',
      fill=True,
      fill_color='crimson'
      ).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48c66770a81302057c6b773d21e31395 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48c66770a81302057c6b773d21e31395&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48c66770a81302057c6b773d21e31395 = L.map(
#                 &quot;map_48c66770a81302057c6b773d21e31395&quot;,
#                 {
#                     center: [38.27312, -98.5821872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5bafee9f17cd185b186d9a04846a5d54 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_5bafee9f17cd185b186d9a04846a5d54.addTo(map_48c66770a81302057c6b773d21e31395);
#
#             var circle_b771f63acb3d6239d3b16dfc9c6068b2 = L.circle(
#                 [64.84507995700051, -147.7220590359997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 38856.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_48c66770a81302057c6b773d21e31395);
#
#
#         var popup_1ded333f9852710fd151eab2a700d0ac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_161eda5e4584a5e50aab19c6e07a7536 = $(`&lt;div id=&quot;html_161eda5e4584a5e50aab19c6e07a7536&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2016: 194.28 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_1ded333f9852710fd151eab2a700d0ac.setContent(html_161eda5e4584a5e50aab19c6e07a7536);
#
#
#
#         circle_b771f63acb3d6239d3b16dfc9c6068b2.bindPopup(popup_1ded333f9852710fd151eab2a700d0ac)
#         ;
#
#
#
#
#             var circle_fab7eae7ccd99e87b530a42d280074ab = L.circle(
#                 [32.84057112200048, -86.63186076199969],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10850.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_48c66770a81302057c6b773d21e31395);
#
#
#         var popup_9db314a9ae7bf0df8087aec9e8350333 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e9377a31d0eecf858a0df4ae6f2ec36 = $(`&lt;div id=&quot;html_8e9377a31d0eecf858a0df4ae6f2ec36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2016: 54.25 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_9db314a9ae7bf0df8087aec9e8350333.setContent(html_8e9377a31d0eecf858a0df4ae6f2ec36);
#
#
#
#         circle_fab7eae7ccd99e87b530a42d280074ab.bindPopup(popup_9db314a9ae7bf0df8087aec9e8350333)
#         ;
#
#
#
#
#             var circle_f6c7994daad2b9296bdca27faacb15d7 = L.circle(
#                 [34.74865012400045, -92.27449074299966],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 58255.99999999999, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_48c66770a81302057c6b773d21e31395);
#
#
#         var popup_6a1247c69743312284adc900ca8fda44 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24422a1cecc2e408d928d35354720d69 = $(`&lt;div id=&quot;html_24422a1cecc2e408d928d35354720d69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2016: 291.28 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_6a1247c69743312284adc900ca8fda44.setContent(html_24422a1cecc2e408d928d35354720d69);
#
#
#
#         circle_f6c7994daad2b9296bdca27faacb15d7.bindPopup(popup_6a1247c69743312284adc900ca8fda44)
#         ;
#
#
#
#
#             var circle_be7548157513ae432303bd71488ccf82 = L.circle(
#                 [34.865970280000454, -111.763811276999

# %%
# Add a HeatMap map to the base map for Diabeties data
lats_longs_weight = list(map(list, zip(overall_average_data_value_2016["latitude"],
                          overall_average_data_value_2016["longitude"],
                          overall_average_data_value_2016["data_value"]
                         )
               )
           )

#Creating a title for the layers in map
fg = folium.FeatureGroup(name="Obesity HeatMap")
fg.add_child(HeatMap(lats_longs_weight))
m.add_child(fg)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd794e0d34ab4ba2cc59d42cfca27cf0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd794e0d34ab4ba2cc59d42cfca27cf0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd794e0d34ab4ba2cc59d42cfca27cf0 = L.map(
#                 &quot;map_dd794e0d34ab4ba2cc59d42cfca27cf0&quot;,
#                 {
#                     center: [38.27312, -98.5821872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c101329a5b32b343f000d30ea34eef48 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_c101329a5b32b343f000d30ea34eef48.addTo(map_dd794e0d34ab4ba2cc59d42cfca27cf0);
#
#             var circle_a2742419e0c066de0844e6178507657c = L.circle(
#                 [64.84507995700051, -147.7220590359997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 38856.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dd794e0d34ab4ba2cc59d42cfca27cf0);
#
#
#         var popup_bd7876b347290561530b18358b8d4024 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dfa1269488a67322768f60830e9e0fe6 = $(`&lt;div id=&quot;html_dfa1269488a67322768f60830e9e0fe6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2015: 194.28 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_bd7876b347290561530b18358b8d4024.setContent(html_dfa1269488a67322768f60830e9e0fe6);
#
#
#
#         circle_a2742419e0c066de0844e6178507657c.bindPopup(popup_bd7876b347290561530b18358b8d4024)
#         ;
#
#
#
#
#             var circle_fe7cbed9562dae303103e7d70c993293 = L.circle(
#                 [32.84057112200048, -86.63186076199969],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10850.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dd794e0d34ab4ba2cc59d42cfca27cf0);
#
#
#         var popup_ecd83eff58edf6037eebc424baaea892 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5bc3adb597fcf1b0cd35561b9b1193bb = $(`&lt;div id=&quot;html_5bc3adb597fcf1b0cd35561b9b1193bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2015: 54.25 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_ecd83eff58edf6037eebc424baaea892.setContent(html_5bc3adb597fcf1b0cd35561b9b1193bb);
#
#
#
#         circle_fe7cbed9562dae303103e7d70c993293.bindPopup(popup_ecd83eff58edf6037eebc424baaea892)
#         ;
#
#
#
#
#             var circle_132ec60f6675f0e6e9a5272b4a6754b2 = L.circle(
#                 [34.74865012400045, -92.27449074299966],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 58255.99999999999, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dd794e0d34ab4ba2cc59d42cfca27cf0);
#
#
#         var popup_85457ffc49123b30023561634d6d453c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93a921ea2e132a0603facfb39df836cd = $(`&lt;div id=&quot;html_93a921ea2e132a0603facfb39df836cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2015: 291.28 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_85457ffc49123b30023561634d6d453c.setContent(html_93a921ea2e132a0603facfb39df836cd);
#
#
#
#         circle_132ec60f6675f0e6e9a5272b4a6754b2.bindPopup(popup_85457ffc49123b30023561634d6d453c)

# %% [markdown]
# 2017 MAP

# %%
#creating the base map
m= folium.Map(location = [38.27312, -98.5821872], zoom_start = 4)

#creating bubble map with restaurant counts per state.
#Loop through each row in the dataframe
for i in range(0,len(location_gdp_df)):
   folium.Circle(
      location=[overall_average_data_value_2017.iloc[i]['latitude'], overall_average_data_value_2017.iloc[i]['longitude']],
      popup=f"GDP 2017: {location_gdp_df.iloc[i]['amount_2017']} (Billions of Dollars)",
      radius=float(location_gdp_df.iloc[i]['amount_2017'])*200,
      color='crimson',
      fill=True,
      fill_color='crimson'
      ).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f38958e990f718c85630b38120bd3ec6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f38958e990f718c85630b38120bd3ec6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f38958e990f718c85630b38120bd3ec6 = L.map(
#                 &quot;map_f38958e990f718c85630b38120bd3ec6&quot;,
#                 {
#                     center: [38.27312, -98.5821872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd2bb3015861253d4392f08df02afcd7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_dd2bb3015861253d4392f08df02afcd7.addTo(map_f38958e990f718c85630b38120bd3ec6);
#
#             var circle_bc66f8e56f3bbf7d5ae8f931161e87a8 = L.circle(
#                 [64.84507995700051, -147.7220590359997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 39394.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f38958e990f718c85630b38120bd3ec6);
#
#
#         var popup_48ce698416139db615069781b3596a21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_80b305ec253e1ccce64f60aa0fbdb0c6 = $(`&lt;div id=&quot;html_80b305ec253e1ccce64f60aa0fbdb0c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2017: 196.97 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_48ce698416139db615069781b3596a21.setContent(html_80b305ec253e1ccce64f60aa0fbdb0c6);
#
#
#
#         circle_bc66f8e56f3bbf7d5ae8f931161e87a8.bindPopup(popup_48ce698416139db615069781b3596a21)
#         ;
#
#
#
#
#             var circle_813559b3c73553f06c73a2f568ae7b48 = L.circle(
#                 [32.84057112200048, -86.63186076199969],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10856.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f38958e990f718c85630b38120bd3ec6);
#
#
#         var popup_61b6bb194b64ffd5acbbb8c70635c317 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d16223bd5a11b53d7bc87d92ca710403 = $(`&lt;div id=&quot;html_d16223bd5a11b53d7bc87d92ca710403&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2017: 54.28 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_61b6bb194b64ffd5acbbb8c70635c317.setContent(html_d16223bd5a11b53d7bc87d92ca710403);
#
#
#
#         circle_813559b3c73553f06c73a2f568ae7b48.bindPopup(popup_61b6bb194b64ffd5acbbb8c70635c317)
#         ;
#
#
#
#
#             var circle_e15f02b0fefcbe1b5de11be317864122 = L.circle(
#                 [34.74865012400045, -92.27449074299966],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 60722.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f38958e990f718c85630b38120bd3ec6);
#
#
#         var popup_48747f5bb3fe9166e1b80163cb63e3e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e164faa4e88ac74f636ab9e5749720c = $(`&lt;div id=&quot;html_3e164faa4e88ac74f636ab9e5749720c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2017: 303.61 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_48747f5bb3fe9166e1b80163cb63e3e0.setContent(html_3e164faa4e88ac74f636ab9e5749720c);
#
#
#
#         circle_e15f02b0fefcbe1b5de11be317864122.bindPopup(popup_48747f5bb3fe9166e1b80163cb63e3e0)
#         ;
#
#
#
#
#             var circle_ac72d02507608a53fcb81e0552c81a9a = L.circle(
#                 [34.865970280000454, -111.76381127699972],

# %%
# Add a HeatMap map to the base map for Diabeties data
lats_longs_weight = list(map(list, zip(overall_average_data_value_2017["latitude"],
                          overall_average_data_value_2017["longitude"],
                          overall_average_data_value_2017["data_value"]
                         )
               )
           )

#Creating a title for the layers in map
fg = folium.FeatureGroup(name="Obesity HeatMap")
fg.add_child(HeatMap(lats_longs_weight))
m.add_child(fg)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f38958e990f718c85630b38120bd3ec6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f38958e990f718c85630b38120bd3ec6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f38958e990f718c85630b38120bd3ec6 = L.map(
#                 &quot;map_f38958e990f718c85630b38120bd3ec6&quot;,
#                 {
#                     center: [38.27312, -98.5821872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd2bb3015861253d4392f08df02afcd7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_dd2bb3015861253d4392f08df02afcd7.addTo(map_f38958e990f718c85630b38120bd3ec6);
#
#             var circle_bc66f8e56f3bbf7d5ae8f931161e87a8 = L.circle(
#                 [64.84507995700051, -147.7220590359997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 39394.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f38958e990f718c85630b38120bd3ec6);
#
#
#         var popup_48ce698416139db615069781b3596a21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_80b305ec253e1ccce64f60aa0fbdb0c6 = $(`&lt;div id=&quot;html_80b305ec253e1ccce64f60aa0fbdb0c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2017: 196.97 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_48ce698416139db615069781b3596a21.setContent(html_80b305ec253e1ccce64f60aa0fbdb0c6);
#
#
#
#         circle_bc66f8e56f3bbf7d5ae8f931161e87a8.bindPopup(popup_48ce698416139db615069781b3596a21)
#         ;
#
#
#
#
#             var circle_813559b3c73553f06c73a2f568ae7b48 = L.circle(
#                 [32.84057112200048, -86.63186076199969],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10856.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f38958e990f718c85630b38120bd3ec6);
#
#
#         var popup_61b6bb194b64ffd5acbbb8c70635c317 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d16223bd5a11b53d7bc87d92ca710403 = $(`&lt;div id=&quot;html_d16223bd5a11b53d7bc87d92ca710403&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2017: 54.28 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_61b6bb194b64ffd5acbbb8c70635c317.setContent(html_d16223bd5a11b53d7bc87d92ca710403);
#
#
#
#         circle_813559b3c73553f06c73a2f568ae7b48.bindPopup(popup_61b6bb194b64ffd5acbbb8c70635c317)
#         ;
#
#
#
#
#             var circle_e15f02b0fefcbe1b5de11be317864122 = L.circle(
#                 [34.74865012400045, -92.27449074299966],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 60722.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f38958e990f718c85630b38120bd3ec6);
#
#
#         var popup_48747f5bb3fe9166e1b80163cb63e3e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e164faa4e88ac74f636ab9e5749720c = $(`&lt;div id=&quot;html_3e164faa4e88ac74f636ab9e5749720c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2017: 303.61 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_48747f5bb3fe9166e1b80163cb63e3e0.setContent(html_3e164faa4e88ac74f636ab9e5749720c);
#
#
#
#         circle_e15f02b0fefcbe1b5de11be317864122.bindPopup(popup_48747f5bb3fe9166e1b80163cb63e3e0)
#         ;

# %% [markdown]
# 2018 MAP

# %%
#creating the base map
m= folium.Map(location = [38.27312, -98.5821872], zoom_start = 4)

#creating bubble map with restaurant counts per state.
#Loop through each row in the dataframe
for i in range(0,len(location_gdp_df)):
   folium.Circle(
      location=[overall_average_data_value_2018.iloc[i]['latitude'], overall_average_data_value_2018.iloc[i]['longitude']],
      popup=f"GDP 2018: {location_gdp_df.iloc[i]['amount_2018']} (Billions of Dollars)",
      radius=float(location_gdp_df.iloc[i]['amount_2018'])*200,
      color='crimson',
      fill=True,
      fill_color='crimson'
      ).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94406f392809a0ca7f1731480a644380 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94406f392809a0ca7f1731480a644380&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94406f392809a0ca7f1731480a644380 = L.map(
#                 &quot;map_94406f392809a0ca7f1731480a644380&quot;,
#                 {
#                     center: [38.27312, -98.5821872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92af075b0b8b7fc3d976733e5c461d74 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_92af075b0b8b7fc3d976733e5c461d74.addTo(map_94406f392809a0ca7f1731480a644380);
#
#             var circle_d7a647c279caffcf2a388f443a521d65 = L.circle(
#                 [64.84507995700051, -147.7220590359997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 40074.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_94406f392809a0ca7f1731480a644380);
#
#
#         var popup_04d927cdb86171a76c790202d8924334 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c5fad74caf508fe266f9a7a27e17b48 = $(`&lt;div id=&quot;html_5c5fad74caf508fe266f9a7a27e17b48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2018: 200.37 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_04d927cdb86171a76c790202d8924334.setContent(html_5c5fad74caf508fe266f9a7a27e17b48);
#
#
#
#         circle_d7a647c279caffcf2a388f443a521d65.bindPopup(popup_04d927cdb86171a76c790202d8924334)
#         ;
#
#
#
#
#             var circle_a3737017b3226d7d712ed0ba33dfd8e7 = L.circle(
#                 [32.84057112200048, -86.63186076199969],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10666.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_94406f392809a0ca7f1731480a644380);
#
#
#         var popup_c6b3b336b8805e59f668122c21251b41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_659efb7d84f48377ecf3cb96164ed7a3 = $(`&lt;div id=&quot;html_659efb7d84f48377ecf3cb96164ed7a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2018: 53.33 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_c6b3b336b8805e59f668122c21251b41.setContent(html_659efb7d84f48377ecf3cb96164ed7a3);
#
#
#
#         circle_a3737017b3226d7d712ed0ba33dfd8e7.bindPopup(popup_c6b3b336b8805e59f668122c21251b41)
#         ;
#
#
#
#
#             var circle_bd268ac9d490db3b7775c0601e2ab01d = L.circle(
#                 [34.74865012400045, -92.27449074299966],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 62966.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_94406f392809a0ca7f1731480a644380);
#
#
#         var popup_d25b125f9ebced90e519c84bdab1dfb8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b99bbfcb546ef6fc53431b6719d011b = $(`&lt;div id=&quot;html_2b99bbfcb546ef6fc53431b6719d011b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2018: 314.83 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_d25b125f9ebced90e519c84bdab1dfb8.setContent(html_2b99bbfcb546ef6fc53431b6719d011b);
#
#
#
#         circle_bd268ac9d490db3b7775c0601e2ab01d.bindPopup(popup_d25b125f9ebced90e519c84bdab1dfb8)
#         ;
#
#
#
#
#             var circle_2b7a3aebea80e2848e089f6413f2b18e = L.circle(
#                 [34.865970280000454, -111.76381127699972],

# %%
# Add a HeatMap map to the base map for Diabeties data
lats_longs_weight = list(map(list, zip(overall_average_data_value_2018["latitude"],
                          overall_average_data_value_2018["longitude"],
                          overall_average_data_value_2018["data_value"]
                         )
               )
           )

#Creating a title for the layers in map
fg = folium.FeatureGroup(name="Obesity HeatMap")
fg.add_child(HeatMap(lats_longs_weight))
m.add_child(fg)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94406f392809a0ca7f1731480a644380 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94406f392809a0ca7f1731480a644380&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94406f392809a0ca7f1731480a644380 = L.map(
#                 &quot;map_94406f392809a0ca7f1731480a644380&quot;,
#                 {
#                     center: [38.27312, -98.5821872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92af075b0b8b7fc3d976733e5c461d74 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_92af075b0b8b7fc3d976733e5c461d74.addTo(map_94406f392809a0ca7f1731480a644380);
#
#             var circle_d7a647c279caffcf2a388f443a521d65 = L.circle(
#                 [64.84507995700051, -147.7220590359997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 40074.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_94406f392809a0ca7f1731480a644380);
#
#
#         var popup_04d927cdb86171a76c790202d8924334 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c5fad74caf508fe266f9a7a27e17b48 = $(`&lt;div id=&quot;html_5c5fad74caf508fe266f9a7a27e17b48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2018: 200.37 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_04d927cdb86171a76c790202d8924334.setContent(html_5c5fad74caf508fe266f9a7a27e17b48);
#
#
#
#         circle_d7a647c279caffcf2a388f443a521d65.bindPopup(popup_04d927cdb86171a76c790202d8924334)
#         ;
#
#
#
#
#             var circle_a3737017b3226d7d712ed0ba33dfd8e7 = L.circle(
#                 [32.84057112200048, -86.63186076199969],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10666.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_94406f392809a0ca7f1731480a644380);
#
#
#         var popup_c6b3b336b8805e59f668122c21251b41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_659efb7d84f48377ecf3cb96164ed7a3 = $(`&lt;div id=&quot;html_659efb7d84f48377ecf3cb96164ed7a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2018: 53.33 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_c6b3b336b8805e59f668122c21251b41.setContent(html_659efb7d84f48377ecf3cb96164ed7a3);
#
#
#
#         circle_a3737017b3226d7d712ed0ba33dfd8e7.bindPopup(popup_c6b3b336b8805e59f668122c21251b41)
#         ;
#
#
#
#
#             var circle_bd268ac9d490db3b7775c0601e2ab01d = L.circle(
#                 [34.74865012400045, -92.27449074299966],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 62966.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_94406f392809a0ca7f1731480a644380);
#
#
#         var popup_d25b125f9ebced90e519c84bdab1dfb8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b99bbfcb546ef6fc53431b6719d011b = $(`&lt;div id=&quot;html_2b99bbfcb546ef6fc53431b6719d011b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2018: 314.83 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_d25b125f9ebced90e519c84bdab1dfb8.setContent(html_2b99bbfcb546ef6fc53431b6719d011b);
#
#
#
#         circle_bd268ac9d490db3b7775c0601e2ab01d.bindPopup(popup_d25b125f9ebced90e519c84bdab1dfb8)
#         ;

# %% [markdown]
# 2019 MAP

# %%
#creating the base map
m= folium.Map(location = [38.27312, -98.5821872], zoom_start = 4)

#creating bubble map with restaurant counts per state.
#Loop through each row in the dataframe
for i in range(0,len(location_gdp_df)):
   folium.Circle(
      location=[overall_average_data_value_2019.iloc[i]['latitude'], overall_average_data_value_2019.iloc[i]['longitude']],
      popup=f"GDP 2019: {location_gdp_df.iloc[i]['amount_2019']} (Billions of Dollars)",
      radius=float(location_gdp_df.iloc[i]['amount_2019'])*200,
      color='crimson',
      fill=True,
      fill_color='crimson'
      ).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47c532833d727ce3d9a9489de1b34bf3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47c532833d727ce3d9a9489de1b34bf3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47c532833d727ce3d9a9489de1b34bf3 = L.map(
#                 &quot;map_47c532833d727ce3d9a9489de1b34bf3&quot;,
#                 {
#                     center: [38.27312, -98.5821872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb6df6dc5d9e0bbd3dbbb2376c35460e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_cb6df6dc5d9e0bbd3dbbb2376c35460e.addTo(map_47c532833d727ce3d9a9489de1b34bf3);
#
#             var circle_e94430b92ceda7ae4aa1de316e146328 = L.circle(
#                 [64.84507995700051, -147.7220590359997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 40686.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_47c532833d727ce3d9a9489de1b34bf3);
#
#
#         var popup_f197fd8fd5ecd2e6a019bf77e3234177 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d9c136fe82dd46fb8a0bf1152351e7d0 = $(`&lt;div id=&quot;html_d9c136fe82dd46fb8a0bf1152351e7d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2019: 203.43 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_f197fd8fd5ecd2e6a019bf77e3234177.setContent(html_d9c136fe82dd46fb8a0bf1152351e7d0);
#
#
#
#         circle_e94430b92ceda7ae4aa1de316e146328.bindPopup(popup_f197fd8fd5ecd2e6a019bf77e3234177)
#         ;
#
#
#
#
#             var circle_6e01ab87b3f3ba68df10037421f79705 = L.circle(
#                 [32.84057112200048, -86.63186076199969],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10686.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_47c532833d727ce3d9a9489de1b34bf3);
#
#
#         var popup_f3af7bcb4d34bfeebeb66938c3a0c590 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d06bfcb31a277484699800e78710cbbc = $(`&lt;div id=&quot;html_d06bfcb31a277484699800e78710cbbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2019: 53.43 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_f3af7bcb4d34bfeebeb66938c3a0c590.setContent(html_d06bfcb31a277484699800e78710cbbc);
#
#
#
#         circle_6e01ab87b3f3ba68df10037421f79705.bindPopup(popup_f3af7bcb4d34bfeebeb66938c3a0c590)
#         ;
#
#
#
#
#             var circle_d6b32684e9668a756e51e15302dc81ac = L.circle(
#                 [34.74865012400045, -92.27449074299966],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 65079.99999999999, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_47c532833d727ce3d9a9489de1b34bf3);
#
#
#         var popup_8265b41274d48993d02f1bf6f9572970 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f0a71f46a74c4ee615a53d3d27e96ef = $(`&lt;div id=&quot;html_0f0a71f46a74c4ee615a53d3d27e96ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2019: 325.4 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_8265b41274d48993d02f1bf6f9572970.setContent(html_0f0a71f46a74c4ee615a53d3d27e96ef);
#
#
#
#         circle_d6b32684e9668a756e51e15302dc81ac.bindPopup(popup_8265b41274d48993d02f1bf6f9572970)
#         ;
#
#
#
#
#             var circle_048888cc11a58521a162d51a0f9f850a = L.circle(
#                 [34.865970280000454, -111.7638112769997

# %%
# Add a HeatMap map to the base map for Diabeties data
lats_longs_weight = list(map(list, zip(overall_average_data_value_2019["latitude"],
                          overall_average_data_value_2019["longitude"],
                          overall_average_data_value_2019["data_value"]
                         )
               )
           )

#Creating a title for the layers in map
fg = folium.FeatureGroup(name="Obesity HeatMap")
fg.add_child(HeatMap(lats_longs_weight))
m.add_child(fg)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47c532833d727ce3d9a9489de1b34bf3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47c532833d727ce3d9a9489de1b34bf3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47c532833d727ce3d9a9489de1b34bf3 = L.map(
#                 &quot;map_47c532833d727ce3d9a9489de1b34bf3&quot;,
#                 {
#                     center: [38.27312, -98.5821872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb6df6dc5d9e0bbd3dbbb2376c35460e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_cb6df6dc5d9e0bbd3dbbb2376c35460e.addTo(map_47c532833d727ce3d9a9489de1b34bf3);
#
#             var circle_e94430b92ceda7ae4aa1de316e146328 = L.circle(
#                 [64.84507995700051, -147.7220590359997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 40686.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_47c532833d727ce3d9a9489de1b34bf3);
#
#
#         var popup_f197fd8fd5ecd2e6a019bf77e3234177 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d9c136fe82dd46fb8a0bf1152351e7d0 = $(`&lt;div id=&quot;html_d9c136fe82dd46fb8a0bf1152351e7d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2019: 203.43 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_f197fd8fd5ecd2e6a019bf77e3234177.setContent(html_d9c136fe82dd46fb8a0bf1152351e7d0);
#
#
#
#         circle_e94430b92ceda7ae4aa1de316e146328.bindPopup(popup_f197fd8fd5ecd2e6a019bf77e3234177)
#         ;
#
#
#
#
#             var circle_6e01ab87b3f3ba68df10037421f79705 = L.circle(
#                 [32.84057112200048, -86.63186076199969],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10686.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_47c532833d727ce3d9a9489de1b34bf3);
#
#
#         var popup_f3af7bcb4d34bfeebeb66938c3a0c590 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d06bfcb31a277484699800e78710cbbc = $(`&lt;div id=&quot;html_d06bfcb31a277484699800e78710cbbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2019: 53.43 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_f3af7bcb4d34bfeebeb66938c3a0c590.setContent(html_d06bfcb31a277484699800e78710cbbc);
#
#
#
#         circle_6e01ab87b3f3ba68df10037421f79705.bindPopup(popup_f3af7bcb4d34bfeebeb66938c3a0c590)
#         ;
#
#
#
#
#             var circle_d6b32684e9668a756e51e15302dc81ac = L.circle(
#                 [34.74865012400045, -92.27449074299966],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 65079.99999999999, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_47c532833d727ce3d9a9489de1b34bf3);
#
#
#         var popup_8265b41274d48993d02f1bf6f9572970 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f0a71f46a74c4ee615a53d3d27e96ef = $(`&lt;div id=&quot;html_0f0a71f46a74c4ee615a53d3d27e96ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GDP 2019: 325.4 (Billions of Dollars)&lt;/div&gt;`)[0];
#                 popup_8265b41274d48993d02f1bf6f9572970.setContent(html_0f0a71f46a74c4ee615a53d3d27e96ef);
#
#
#
#         circle_d6b32684e9668a756e51e15302dc81ac.bindPopup(popup_8265b41274d48993d02f1bf6f9572970)

# %% [markdown]
# The Average GDP and Obesity rates
